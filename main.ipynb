# %% [markdown]
# # Topic Model and Correlation

# %%
import warnings
warnings.filterwarnings('ignore')
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
import spacy
import scipy
import matplotlib.pyplot as plt
import seaborn as sns
import os
import pickle

from wordcloud import WordCloud
plt.style.use('seaborn-darkgrid')
# %matplotlib inline

# %%
#load datset
fname = 'data2.txt'
articles = []
errs = 0
with open(fname, 'r') as f:
    art = []
    while True:
        line = f.readline()
        if not line:
            break
        if 'URL' in line:
            if art != []:
                paper = ' '.join(art)
                if 'No corrections appeared in print' not in paper: #error papers
                    articles.append(paper)
                else:
                    errs += 1
            art = []
        elif line not in {'\n', ' '}:
            art.append(line.rstrip('\n'))

# %%
print(len(articles), errs)
# Out:
# 98 0

# %%
class Vocab(TfidfVectorizer):
    def __init__(self, texts, **kwargs):
        super(Vocab, self).__init__(**kwargs)
        self.fit(texts)

    def __len__(self):
        return len(self.vocabulary_)
    
    def _to_bow(self, sent):
        prep = self.build_preprocessor()
        analyzer = self.build_analyzer()
        seq = analyzer(prep(sent))
        return [w for w in seq if w in self.vocabulary_]

    def _to_indices(self, sent):
        return [self.vocabulary_[w] for w in self._to_bow(sent)]


def save_model(model, filename):
    print('saving model to %s ...' % filename)
    pickle.dump(model, open(filename, 'wb'))

def load_model(filename):
    print('loading model from %s ...' % filename)
    return pickle.load(open(filename, 'rb'))

# %%
nlp = spacy.load('en_core_web_sm')
class LemmaTokenizer(object):
    def __init__(self):
        self.wnl = spacy.load('en_core_web_sm', disable=['parser', 'ner'])
    def __call__(self, doc):
        return [t.lemma_ for t in self.wnl(doc)]

# %%
vocab_size = 15000

kwargs = {'stop_words': 'english', 'max_df': 0.5, 'min_df': 3, 'ngram_range': (1, 1),
            'max_features': vocab_size, 'strip_accents': 'unicode'}
try:
    vocab = load_model('vocab.mode')
except:
    print('... creating new model')
    vocab = Vocab(articles, tokenizer=LemmaTokenizer(), **kwargs)
# Out:
# loading model from vocab.mode ...
# ... creating new model

# %%
print(len(vocab))
save_model(vocab, 'model/vocab.mod')
# Out:
# 376
# saving model to model/vocab.mod ...

# %%
text = 'mr. trump and colleagues\n^ are going to do something about it. Australia is highly concerned.'
print(vocab._to_bow(text))
# Out:
# []

# %% [markdown]
# ## Topic extraction

# %%
import pyLDAvis
pyLDAvis.enable_notebook()
import gensim

# %%
arts_in_bow = [vocab._to_bow(art) for art in articles]
dct = gensim.corpora.Dictionary(arts_in_bow)
corpus = [dct.doc2bow(a) for a in arts_in_bow]

# %%
num_topics = 20
ldamodel = gensim.models.ldamodel.LdaModel(corpus, num_topics=num_topics, id2word=dct, passes=5, 
                                           alpha=[0.01]*num_topics, eta=[0.01]*len(dct.keys()))
if not os.path.exists('model'):
    os.makedirs('model')
ldamodel.save('model/lda.gensim')
topics = ldamodel.print_topics(num_words=30)
for topic in topics:
    print(topic)
# Out:
# (0, '0.017*"3d" + 0.017*"journey" + 0.016*"american" + 0.014*")" + 0.014*"earth" + 0.014*"star" + 0.014*"(" + 0.013*"2008" + 0.013*"adaptation" + 0.013*"center" + 0.010*"bob" + 0.010*"chris" + 0.010*"ensemble" + 0.010*"chalamet" + 0.010*"amy" + 0.010*"timotha" + 0.009*"eliza" + 0.009*"emma" + 0.009*"louisa" + 0.009*"greta" + 0.009*"massachusetts" + 0.009*"\'s" + 0.009*"come" + 0.009*"watson" + 0.009*"laura" + 0.009*"cooper" + 0.009*"seventh" + 0.009*"dern" + 0.009*"saoirse" + 0.009*"letts"')
# (11, '0.035*"star" + 0.035*"woodley" + 0.035*"support" + 0.035*"patient" + 0.035*"play" + 0.035*"cancer" + 0.035*"elgort" + 0.018*"]" + 0.018*"love" + 0.018*"fall" + 0.018*"year" + 0.018*"base" + 0.018*";" + 0.018*"dern" + 0.018*"lancaster" + 0.018*"force" + 0.018*"attend" + 0.018*"playing" + 0.018*"meet" + 0.018*"trammell" + 0.018*"sixteen" + 0.018*"parent" + 0.018*"waters" + 0.018*"nat" + 0.018*"boone" + 0.018*"john" + 0.018*"group" + 0.018*"romantic" + 0.018*"film[4][5][6" + 0.018*"hazel"')
# (12, '0.074*"forest" + 0.040*"\'s" + 0.038*""" + 0.037*"month" + 0.037*"kill" + 0.037*"bleak" + 0.037*"ability" + 0.037*"rest" + 0.037*"pursue" + 0.037*"place" + 0.037*"wolf" + 0.037*"live" + 0.037*"flesh" + 0.037*"winter" + 0.037*"long" + 0.037*"spot" + 0.037*"cold" + 0.037*"hunt" + 0.037*"resist" + 0.037*"a€" + 0.037*"feyre" + 0.037*"survival" + 0.037*"deer" + 0.037*"fight" + 0.003*"harry" + 0.002*"potter" + 0.002*"series" + 0.002*"goblet" + 0.001*"percy" + 0.001*"character"')
# (13, '0.040*"(" + 0.040*")" + 0.026*"r." + 0.026*"sean" + 0.026*"new" + 0.026*"ring" + 0.013*"write" + 0.013*"united" + 0.013*"states" + 0.013*"2003" + 0.013*"cast" + 0.013*"cinema" + 0.013*"davy" + 0.013*"christopher" + 0.013*"j." + 0.013*"dominic" + 0.013*"elijah" + 0.013*"lee" + 0.013*"hugo" + 0.013*"bloom" + 0.013*"venture" + 0.013*"tolkien" + 0.013*"jackson" + 0.013*"john" + 0.013*"distribute" + 0.013*"orlando" + 0.013*"bean" + 0.013*"fellowship" + 0.013*"rhys" + 0.013*"andy"')
# (14, '0.064*"meluha" + 0.043*"empire" + 0.043*"immortal" + 0.043*":" + 0.022*"lord" + 0.021*"great" + 0.021*"period" + 0.021*"trilogy" + 0.021*"face" + 0.021*"combo" + 0.021*"inhabitant" + 0.021*"bc" + 0.021*"ruler" + 0.021*"proud" + 0.021*"indians" + 0.021*"create" + 0.021*"severe" + 0.021*"century" + 0.021*"valley" + 0.021*"perfect" + 0.021*"suryavanshi" + 0.021*"vayuputra" + 0.021*"river" + 0.021*"mistakenly" + 0.021*"oath" + 0.021*"primary" + 0.021*"civilisation" + 0.021*"modern" + 0.021*"secret" + 0.021*"peril"')
# (15, '0.024*"(" + 0.022*")" + 0.021*"journey" + 0.018*"3d" + 0.015*"american" + 0.014*"]" + 0.014*"center" + 0.013*"2008" + 0.013*"play" + 0.012*"earth" + 0.012*"release" + 0.012*"star" + 0.011*"patient" + 0.011*"cystic" + 0.010*"josh" + 0.009*"2019" + 0.008*"romantic" + 0.008*"warner" + 0.007*"eric" + 0.007*"notably" + 0.007*"\'s" + 0.007*"elgort" + 0.007*"promote" + 0.007*"fantasy" + 0.007*"multiple" + 0.007*"cancer" + 0.007*"time" + 0.007*"adaptation" + 0.007*"force" + 0.007*"1864"')
# (16, '0.031*"]" + 0.031*")" + 0.031*"2019" + 0.031*"cystic" + 0.031*"(" + 0.015*"united" + 0.015*"lu" + 0.015*"gross" + 0.015*"mixed" + 0.015*"stay" + 0.015*"young" + 0.015*"foot" + 0.015*"review" + 0.015*"receive" + 0.015*"baldoni" + 0.015*"debut" + 0.015*"try" + 0.015*"cbs" + 0.015*"states" + 0.015*"richardson" + 0.015*"iaconis" + 0.015*"claire" + 0.015*"certain" + 0.015*"million" + 0.015*"apart" + 0.015*"patient" + 0.015*"despite" + 0.015*"directorial" + 0.015*"write" + 0.015*"force"')
# (17, '0.089*"harry" + 0.081*"potter" + 0.042*"\'s" + 0.031*"series" + 0.029*"(" + 0.024*")" + 0.022*"base" + 0.021*"j." + 0.020*"fantasy" + 0.020*"distribute" + 0.020*"rowling" + 0.019*"warner" + 0.019*"k." + 0.017*"follow" + 0.016*"radcliffe" + 0.016*"david" + 0.016*"produce" + 0.015*"year" + 0.014*"bros" + 0.014*"star" + 0.014*"rupert" + 0.014*"watson" + 0.014*"ron" + 0.014*"emma" + 0.014*"weasley" + 0.014*"daniel" + 0.014*"grint" + 0.014*"grang" + 0.014*"hermione" + 0.014*"steve"')
# (18, '0.128*"release" + 0.038*"\'s" + 0.031*"potter" + 0.029*"harry" + 0.015*"stone" + 0.009*"hogwarts" + 0.009*"witchcraft" + 0.008*"hermione" + 0.008*"series" + 0.007*"begin" + 0.007*"columbus" + 0.007*"school" + 0.007*"david" + 0.007*"wizardry" + 0.007*"watson" + 0.007*"heyman" + 0.007*"ron" + 0.007*"story" + 0.007*"grang" + 0.006*"philosopher" + 0.006*"star" + 0.006*"instalment" + 0.006*"kloves" + 0.006*"grint" + 0.006*"states" + 0.006*"pictures" + 0.006*"follow" + 0.006*"year" + 0.006*"base" + 0.006*")"')
# (19, '0.057*"jackson" + 0.057*"series" + 0.057*"\'s" + 0.057*"character" + 0.056*"percy" + 0.042*"riordan" + 0.042*"appear" + 0.042*"narrator" + 0.042*"hero" + 0.028*""" + 0.028*"protagonist" + 0.028*"greek" + 0.028*"rick" + 0.014*"blood" + 0.014*"olympus" + 0.014*"/" + 0.014*"ongoing" + 0.014*"collection" + 0.014*"seven" + 0.014*"apollo" + 0.014*"title" + 0.014*"god" + 0.014*"lose" + 0.014*"olympians" + 0.014*"fictional" + 0.014*"perseus" + 0.014*"serve" + 0.014*"chronicle" + 0.014*"demigod" + 0.014*"crossover"')

# %%
ldamodel.get_document_topics(dct.doc2bow(vocab._to_bow(articles[0])))
# Out:
# [(17, 0.9940994)]

# %%
ldamodel.state.get_lambda().shape
# Out:
# (20, 376)

# %%
ldamodel.num_terms
# Out:
# 376

# %%
def get_topics(lda, num_words=30):
    l_topics = []
    for i in range(lda.num_topics):
        topic = ldamodel.state.get_lambda()[i]
        topic = topic / np.sum(topic)
        mx_indices = sorted(range(lda.num_terms), key=lambda a: topic[a], reverse=True)[:num_words]
        words = [lda.id2word[j] for j in mx_indices]
        l_topics.append(words)
    return l_topics

# %%
print(get_topics(ldamodel))
# Out:
# [['3d', 'journey', 'american', ')', 'earth', 'star', '(', '2008', 'adaptation', 'center', 'bob', 'chris', 'ensemble', 'chalamet', 'amy', 'timotha', 'eliza', 'emma', 'louisa', 'greta', 'massachusetts', "'s", 'come', 'watson', 'laura', 'cooper', 'seventh', 'dern', 'saoirse', 'letts'], ['write', '2019', 'star', 'emma', 'march', 'drama', 'watson', 'american', 'adaptation', 'cast', 'odenkirk', 'life', 'meg', 'pugh', 'streep', 'age', 'meryl', 'century', 'alcott', 'james', 'betha€”in', 'little', 'concord', '1868', '19th', 'e', 'louis', 'gerwig', 'garrel', 'comprise'], [')', '(', 'sean', 'r.', 'ring', 'rhys', 'production', 'viggo', 'fantasy', 'cate', 'international', 'united', 'bloom', 'john', 'new', 'tolkien', 'wingnut', 'series', 'tyler', 'monaghan', 'boyd', 'epic', '2003', 'adventure', 'line', 'dominic', 'bean', 'davy', '2002', 'ensemble'], ['2019', 'patient', ')', 'play', 'american', ']', '(', 'force', 'romantic', 'elgort', 'drama', 'cancer', 'cystic', 'claire', 'distance', 'lionsgate.[1', 'release', 'star', '91', 'fibrosis', 'iaconis', 'foot', 'away', 'million', '$', 'suffer', 'try', 'tobias', 'march', 'inspire'], ['cystic', '(', ']', '2019', 'worldwide', ')', 'suffer', 'drama', 'american', 'distance', 'away', 'inspire', 'young', 'haley', '6', '91', 'tobias', 'wineland', '$', 'cole', 'foot', 'fibrosis', 'justin', 'despite', 'apart', 'richardson', 'lionsgate.[1', 'march', 'critic', 'mikki'], ["'s", 'series', 'jackson', 'character', '3d', ')', 'percy', 'riordan', 'appear', 'hero', 'journey', 'narrator', 'rick', 'center', '"', 'protagonist', '(', 'greek', 'earth', '2008', 'release', 'line', 'produce', 'new', '3-d', 'fantasy', 'main', 'greco', 'sequel', 'time'], ['journey', '3d', '(', ')', '2008', 'earth', 'center', "'s", 'new', 'cinema', 'line', 'produce', 'adventure', 'fantasy', 'science', 'josh', 'brevig', '11', 'action', 'verne', 'adaptation', 'theater', 'star', 'jules', 'picture', 'brendan', 'adapt', 'bros', 'anita', 'briem'], ['percy', 'jackson', "'s", 'series', 'hero', 'character', 'narrator', 'appear', 'riordan', 'greek', 'rick', '"', 'protagonist', 'half', 'story', 'trial', 'main', 'lose', 'roman', 'book', 'perseus', 'camp', 'egyptian', 'make', 'crossover', 'sequel', 'god', 'demigod', 'serve', '&'], ["'s", 'series', 'jackson', 'percy', '"', 'forest', 'narrator', 'appear', 'character', 'hero', 'riordan', ')', '(', 'chronicle', 'protagonist', 'rick', 'greek', 'write', 'ensemble', 'r.', 'ring', 'sean', 'place', 'survival', 'resist', 'spot', 'fight', 'cold', 'long', 'wolf'], ['david', "'s", 'harry', 'potter', ']', 'half', 'blood', 'prince', 'voldemort', 'yates', 'bro', 'follow', 'lord', 'story', 'instalment', 'heyman', 'kloves', 'steve', 'series', 'receive', 'fall', 'make', '2005', 'love', 'write', 'hogwart', 'k.', 'year', 'warner', 'produce'], [')', '(', 'new', 'sean', 'ring', 'r.', 'epic', 'mckellen', 'mortensen', 'cate', 'return', 'zealand', 'lord', 'line', 'boyd', 'christopher', 'weaving', 'include', 'billy', 'series', 'ian', 'viggo', 'cast', '2003', 'liv', 'tyler', 'fantasy', 'hugo', 'king', 'feature'], ['star', 'woodley', 'support', 'patient', 'play', 'cancer', 'elgort', ']', 'love', 'fall', 'year', 'base', ';', 'dern', 'lancaster', 'force', 'attend', 'playing', 'meet', 'trammell', 'sixteen', 'parent', 'waters', 'nat', 'boone', 'john', 'group', 'romantic', 'film[4][5][6', 'hazel'], ['forest', "'s", '"', 'kill', 'month', 'ability', 'bleak', 'place', 'pursue', 'rest', 'wolf', 'flesh', 'live', 'long', 'winter', 'cold', 'spot', 'hunt', 'resist', 'a€', 'feyre', 'deer', 'fight', 'survival', 'harry', 'potter', 'series', 'goblet', 'percy', 'character'], ['(', ')', 'r.', 'sean', 'new', 'ring', 'write', 'united', 'states', '2003', 'cast', 'cinema', 'davy', 'christopher', 'j.', 'dominic', 'elijah', 'lee', 'hugo', 'bloom', 'venture', 'tolkien', 'jackson', 'john', 'distribute', 'orlando', 'bean', 'fellowship', 'rhys', 'andy'], ['meluha', 'empire', 'immortal', ':', 'lord', 'great', 'period', 'trilogy', 'face', 'combo', 'inhabitant', 'bc ...

# %%
probs = ldamodel.state.get_lambda()
probs = probs / np.sum(probs, axis=1, keepdims=True)

# %%
np.sum(probs[0])
# Out:
# 0.99999994

# %%
from numpy.linalg import norm

N = norm(probs, axis=1)
heatmap = (probs @ probs.T) / np.einsum('i, j->ij', N, N)

# %%
plt.figure(figsize=(8,8))
plt.imshow(heatmap, cmap='coolwarm')
plt.grid(None)
ticks = list(map(lambda a: 'topic %d' % a, range(ldamodel.num_topics)))
plt.xticks(np.arange(ldamodel.num_topics), ticks, rotation=45)
plt.yticks(np.arange(ldamodel.num_topics), ticks, rotation=45)
plt.colorbar()
plt.show()

# %%
from wordcloud import WordCloud

# %%
def vis_topic(topic, save_fname=None, **kwargs):
    wordcloud = WordCloud(**kwargs).generate(' '.join(topic))
    if save_fname is not None:
        wordcloud.to_file(save_fname)
    return wordcloud
num_topics = ldamodel.num_topics
w = h = 200
import cv2 as cv
mask = cv.imread('img/circle.jpg')
wcargs = {'width': w, 'height': h, 'background_color': "rgba(255, 255, 255, 0)", 'mode': "RGBA",
        'max_font_size': 100, 'min_font_size': 10, 'colormap': 'Paired', 'mask': mask}

# %%
topics = get_topics(ldamodel)
print(topics[0])
# Out:
# ['3d', 'journey', 'american', ')', 'earth', 'star', '(', '2008', 'adaptation', 'center', 'bob', 'chris', 'ensemble', 'chalamet', 'amy', 'timotha', 'eliza', 'emma', 'louisa', 'greta', 'massachusetts', "'s", 'come', 'watson', 'laura', 'cooper', 'seventh', 'dern', 'saoirse', 'letts']

# %%
fig, axes = plt.subplots(num_topics // 5, 5, figsize=(16, 14))
for i in range(num_topics):
    r, c = i // 5, i % 5
    
    wordcloud = vis_topic(topics[i], **wcargs)
    axes[r, c].imshow(wordcloud, interpolation="bilinear")
    axes[r, c].axis("off")
    axes[r, c].set_title('Topic %d' % i)

wordcloud.to_file('wordcloud.png')
plt.show()

# %%
import matplotlib.image as mpimg
from matplotlib.offsetbox import TextArea, DrawingArea, OffsetImage, AnnotationBbox

topic_clouds = [vis_topic(topic, **wcargs).to_array() for topic in topics]
coords = np.random.randint(num_topics // 2, size=(num_topics, 2))
print(topic_clouds[0].shape)
# Out:
# (283, 284, 4)

# %%
def draw_line(ax, p1, p2, linewidth, color='black'):
    ax.annotate(p2,
                xy=p2, xycoords='data',
                xytext=p1, size=20, va="center", ha="center",
                arrowprops=dict(arrowstyle="<|-|>",
                                connectionstyle="arc3,rad=-0.2",
                                fc="w", linewidth=linewidth, color=color))

def im_annot(im_array, coords, zoom=0.5):
    imagebox = OffsetImage(im_array, interpolation='bilinear', zoom=zoom)
    annot = AnnotationBbox(imagebox, coords, 
                        bboxprops=dict(facecolor='none', edgecolor='none', boxstyle='round'),
                      )
    return annot

# %%
zoom = 1
margin = zoom // 2
lim = np.max(coords, axis=0)

fig, ax = plt.subplots(figsize=(16, 16))

ax.set_xlim(-0.5, lim[0] + 0.5)
ax.set_ylim(-0.5, lim[1] + 0.5)

for i, topic in enumerate(topic_clouds):
    ax.add_artist(im_annot(topic, coords[i]))
    for j in range(num_topics):
        if i >= j:
            continue
        link = heatmap[i, j]
        if link >= 0.3:
            draw_line(ax, coords[i], coords[j], link * 4)
    
ax.set_yticklabels([])
ax.set_xticklabels([])

plt.grid(None)

#plt.draw()
plt.show()

# %%
def read_corpus(corpus, tokens_only=False):
    for i, line in enumerate(corpus):
        if tokens_only:
            yield line # use this func to tokenize a line
        else:
            # For training data, add tags
            yield gensim.models.doc2vec.TaggedDocument(line, [i])

# %%
data = list(read_corpus(arts_in_bow))

# %%
data[0]
# Out:
# TaggedDocument(words=['harry', 'potter', 'series', 'base', 'j.', 'k.', 'rowling', 'series', 'distribute', 'warner', 'bros', 'fantasy', 'begin', 'harry', 'potter', 'philosopher', "'s", 'stone', '(', '2001', ')', 'harry', 'potter', 'a€', '"', '(', ']', 'series', '(', ')', 'mark', ']'], tags=[0])

# %% [markdown]
# Now how we retrieve topics from unseen document?

# %%
model = gensim.models.doc2vec.Doc2Vec(vector_size=100, min_count=2, epochs=40)
model.build_vocab(data)
# %time model.train(data, total_examples=model.corpus_count, epochs=model.epochs)
# Out:
# Wall time: 392 ms

# %%
def sort_relevant(subj, model, data, vocab, topn=5):
    s = vocab._to_bow(subj)
    rep = model.infer_vector(s)
    print(s)
    sims = model.docvecs.most_similar([rep], topn=topn)
    return sims

# %%
your_question = 'Harry Potter'
print('Your question is: %s' %your_question)

sims = sort_relevant(your_question, model, data, vocab, 10)
for i, perti in enumerate(sims):

    print(u'TOP %s RELEVANT %s: «%s»\n' % (i, perti, articles[perti[0]]))
# Out:
# Your question is: Harry Potter
# ['harry', 'potter']
# TOP 0 RELEVANT (45, 0.92229825258255): «Harry Potter and the Goblet of Fire is a 2005 fantasy film directed by Mike Newell and distributed by Warner Bros. Pictures, based on J. K. Rowling's 2000 novel of the same name. Produced by David Heyman and written by Steve Kloves, it is the sequel to Harry Potter and the Prisoner of Azkaban (2004) and the fourth instalment in the Harry Potter film series. The film stars Daniel Radcliffe as Harry Potter, with Rupert Grint as Ron Weasley, and Emma Watson as Hermione Granger. Its story follows Harry's fourth year at Hogwarts as he is chosen by the Goblet of Fire to compete in the Triwizard Tournament. »
#
# TOP 1 RELEVANT (36, 0.9201635718345642): «Harry Potter and the Goblet of Fire is a 2005 fantasy film directed by Mike Newell and distributed by Warner Bros. Pictures, based on J. K. Rowling's 2000 novel of the same name. Produced by David Heyman and written by Steve Kloves, it is the sequel to Harry Potter and the Prisoner of Azkaban (2004) and the fourth instalment in the Harry Potter film series. The film stars Daniel Radcliffe as Harry Potter, with Rupert Grint as Ron Weasley, and Emma Watson as Hermione Granger. Its story follows Harry's fourth year at Hogwarts as he is chosen by the Goblet of Fire to compete in the Triwizard Tournament. »
#
# TOP 2 RELEVANT (9, 0.9008842706680298): «Harry Potter and the Philosopher's Stone (released in the United States and India as Harry Potter and the Sorcerer's Stone) is a 2001 fantasy film directed by Chris Columbus and distributed by Warner Bros. Pictures, based on J. K. Rowling's 1997 novel of the same name. Produced by David Heyman and screenplay by Steve Kloves, it is the first instalment of the Harry Potter film series. The film stars Daniel Radcliffe as Harry Potter, with Rupert Grint as Ron Weasley, and Emma Watson as Hermione Granger. Its story follows Harry Potter's first year at Hogwarts School of Witchcraft and Wizardry as he discovers that he is a famous wizard and begins his education. »
#
# TOP 3 RELEVANT (27, 0.8782267570495605): «Harry Potter and the Prisoner of Azkaban is a 2004 fantasy film directed by Alfonso CuarÃ³n and distributed by Warner Bros. Pictures, based on J. K. Rowling's 1999 novel of the same name. Produced by Chris Columbus, David Heyman, and Mark Radcliffe and written by Steve Kloves, it is the sequel to Harry Potter and the Chamber of Secrets (2002) and the third instalment in the Harry Potter film series. The film stars Daniel Radcliffe as Harry Potter, with Rupert Grint as Ron Weasley, and Emma Watson as Hermione Granger. Its story follows Harry Potter's third year at Hogwarts as he is informed that a prisoner named Sirius Black has escaped from Azkaban and intends to kill him. »
#
# TOP 4 RELEVANT (18, 0.8536480665206909): «Harry Potter and the Chamber of Secrets is a 2002 fantasy film directed by Chris Columbus and distributed by Warner Bros. Pictures, based on J. K. Rowling's 1998 novel of the same name. Produced by David Heyman and written by Steve Kloves, it is the sequel to Harry Potter and the Philosopher's Stone (2001) and the second instalment in the Harry Potter film series. The film stars Daniel Radcliffe as Harry Potter